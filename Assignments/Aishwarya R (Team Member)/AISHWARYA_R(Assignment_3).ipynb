# %% [markdown]
# **Assignment -3**
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Assignment Date</p>
# </blockquote></th>
# <th><blockquote>
# <p>01 October 2022</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Student Name</p>
# </blockquote></td>
# <td><blockquote>
# <p>Aishwarya R</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Student Roll Number</p>
# </blockquote></td>
# <td><blockquote>
# <p>811519104006</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>Maximum Marks</p>
# </blockquote></td>
# <td><blockquote>
# <p>2 Marks</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20139in" />
# >
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20139in" />
#
# \[2\]: Sex Length Diameter Height Whole weight Shucked weight Viscera
# weight \\
#
# <table>
# <thead>
# <tr class="header">
# <th>0 M</th>
# <th>0.455</th>
# <th><blockquote>
# <p>0.365 0.095</p>
# </blockquote></th>
# <th><blockquote>
# <p>0.5140</p>
# </blockquote></th>
# <th>0.2245</th>
# <th>0.1010</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>1 M</td>
# <td>0.350</td>
# <td><blockquote>
# <p>0.265 0.090</p>
# </blockquote></td>
# <td><blockquote>
# <p>0.2255</p>
# </blockquote></td>
# <td>0.0995</td>
# <td>0.0485</td>
# </tr>
# <tr class="even">
# <td>2 F</td>
# <td>0.530</td>
# <td><blockquote>
# <p>0.420 0.135</p>
# </blockquote></td>
# <td><blockquote>
# <p>0.6770</p>
# </blockquote></td>
# <td>0.2565</td>
# <td>0.1415</td>
# </tr>
# <tr class="odd">
# <td>3 M</td>
# <td>0.440</td>
# <td><blockquote>
# <p>0.365 0.125</p>
# </blockquote></td>
# <td><blockquote>
# <p>0.5160</p>
# </blockquote></td>
# <td>0.2155</td>
# <td>0.1140</td>
# </tr>
# </tbody>
# </table>
#
# > 4 I 0.330 0.255 0.080 0.2050 0.0895 0.0395
# >
# > Shell weight Rings
#
# <table>
# <thead>
# <tr class="header">
# <th>0</th>
# <th>0.150</th>
# <th><blockquote>
# <p>15</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>1</td>
# <td>0.070</td>
# <td><blockquote>
# <p>7</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>2</td>
# <td>0.210</td>
# <td><blockquote>
# <p>9</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>3</td>
# <td>0.155</td>
# <td><blockquote>
# <p>10</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>4</td>
# <td>0.055</td>
# <td><blockquote>
# <p>7</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image3.png" style="width:0.63472in;height:0.2in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image4.png" style="width:5.66667in;height:0.31944in" />
#
# > \<class
# > 'pandas.core.frame.DataFrame'\>
# > RangeIndex: 4177 entries, 0 to
# > 4176 Data columns (total 9
# > columns):
# > \# Column Non-Null Count Dtype --- ------ -------------- -----
# >
# > 0 Sex 4177 non-null object
# >
# > 1 Length 4177 non-null float64
# >
# > 2 Diameter 4177 non-null float64
# >
# > 3 Height 4177 non-null float64 4 Whole weight 4177 non-null float64 5
# > Shucked weight 4177 non- float64 null
# >
# > 6 Viscera weight 4177 non-
#
# null
#
# > float64
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image5.png" style="width:6.55556in;height:1.44444in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.2125in;height:0.20238in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52778in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.2125in;height:0.20238in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image9.png" style="width:1.05833in;height:0.20063in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.2125in;height:0.20238in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.73889in;height:0.1997in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image12.png" style="width:0.95278in;height:0.20059in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image13.png" style="width:1.16389in;height:0.20067in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" />
# >
# > 7 Shell weight 4177 non-null float64 8 Rings 4177 non-null int64
# > dtypes: float64(7), int64(1), object(1) memory usage: 293.8+ KB
#
# 1
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image14.png" style="width:6.55556in;height:0.51389in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10555in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10555in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image16.png" style="width:0.84444in;height:0.19987in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52778in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image17.png" style="width:1.58611in;height:0.20014in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20278in" />
#
# <table>
# <thead>
# <tr class="header">
# <th>M</th>
# <th><blockquote>
# <p>1528</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>I</td>
# <td><blockquote>
# <p>1342</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>F</td>
# <td><blockquote>
# <p>1307</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > Name: Sex, dtype: int64
# > 0.625 94
# > 0.550 94
# > 0.575 93
# > 0.580 92
# > 0.600 87
# > ..
# >
# > 0.075 1 0.815
# > 1 0.110 1
# > 0.150 1
# > 0.800 1
# > Name: Length, Length: 134, dtype: int64 0.450 139
# > 0.475 120
# > 0.400 111
# > 0.500 110
# > 0.470 100
# > …
# > 0.610 1 0.650
# > 1
# > 1 0.620 0.095 1
# > 0.615 1
# > Name: Diameter, Length: 111, dtype: int64 0.150 267
# > 0.140 220
# > 0.155 217
# > 0.175 211
# > 0.160 205
# > 0.125 202
# > 0.165 193
# > 0.135 189
# > 0.145 182
# > 0.130 169
# > 0.120 169
# > 0.170 160
# > 0.100 145
# > 0.110 135
# > 0.115 133
# > 0.180 131
# > 0.090 124
# > 0.105 114
#
# 2
#
# > 0.185 103
# > 0.190 103
# > 0.095 91 0.195
# > 78 0.080 76
# > 0.085 74 0.200
# > 68 0.075 61
# > 0.070 47 0.205
# > 45 0.065 39
# > 0.215 31 0.060
# > 26 0.055 25
# > 0.210 23 0.050
# > 18 0.220
# > 17 0.040 13 0.225
# > 13 0.045 11
# > 0.230 10
# > 0.030 6 0.035
# > 6 0.235 6
# > 0.025 5 0.240
# > 4 0.250 3
# > 0.020 2 0.015
# > 2 0.000 2
# > 0.010 1 0.515
# > 1
# > 1.130 1
# > Name: Height, dtype: int64
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>0.2225</p>
# </blockquote></th>
# <th><blockquote>
# <p>8</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>1.1345</p>
# </blockquote></td>
# <td><blockquote>
# <p>7</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.9700</p>
# </blockquote></td>
# <td><blockquote>
# <p>7</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>0.4775</p>
# </blockquote></td>
# <td><blockquote>
# <p>7</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.1960</p>
# </blockquote></td>
# <td><blockquote>
# <p>7</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# ..
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>0.0475</p>
# </blockquote></th>
# <th><blockquote>
# <p>1</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>1.8930</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>1.8725</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>2.1055</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>1.9485</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > Name: Whole weight, Length: 2429, dtype: int64
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>0.1750</p>
# </blockquote></th>
# <th><blockquote>
# <p>11</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>0.2505</p>
# </blockquote></td>
# <td><blockquote>
# <p>10</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.0970</p>
# </blockquote></td>
# <td><blockquote>
# <p>9</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>0.0960</p>
# </blockquote></td>
# <td><blockquote>
# <p>9</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# 3
#
# > 0.4190 9
#
# ..
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>0.4175</p>
# </blockquote></th>
# <th><blockquote>
# <p>1</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>0.1935</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.1790</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>0.1275</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.9455</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > Name: Shucked weight, Length: 1515, dtype: int64
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>0.1715</p>
# </blockquote></th>
# <th><blockquote>
# <p>15</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>0.1960</p>
# </blockquote></td>
# <td><blockquote>
# <p>14</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.0575</p>
# </blockquote></td>
# <td><blockquote>
# <p>13</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>0.0610</p>
# </blockquote></td>
# <td><blockquote>
# <p>13</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.0370</p>
# </blockquote></td>
# <td><blockquote>
# <p>13</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# ..
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>0.4270</p>
# </blockquote></th>
# <th><blockquote>
# <p>1</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>0.4075</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.4920</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>0.4650</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.5260</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > Name: Viscera weight, Length: 880, dtype: int64
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>0.2750</p>
# </blockquote></th>
# <th><blockquote>
# <p>43</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>0.2500</p>
# </blockquote></td>
# <td><blockquote>
# <p>42</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.2650</p>
# </blockquote></td>
# <td><blockquote>
# <p>40</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>0.3150</p>
# </blockquote></td>
# <td><blockquote>
# <p>40</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.1850</p>
# </blockquote></td>
# <td><blockquote>
# <p>40</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# ..
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>0.0060</p>
# </blockquote></th>
# <th><blockquote>
# <p>1</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>0.6460</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.5010</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>0.3295</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>0.0920</p>
# </blockquote></td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > Name: Shell weight, Length: 926, dtype: int64 4
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image18.png" style="width:6.51389in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image16.png" style="width:0.84583in;height:0.2002in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52778in;height:0.20106in" />
#
# <table>
# <thead>
# <tr class="header">
# <th>9</th>
# <th><blockquote>
# <p>689</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>10</td>
# <td><blockquote>
# <p>634</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>8</td>
# <td><blockquote>
# <p>568</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>11</td>
# <td><blockquote>
# <p>487</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>7</td>
# <td><blockquote>
# <p>391</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>12</td>
# <td><blockquote>
# <p>267</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>6</td>
# <td><blockquote>
# <p>259</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>13</td>
# <td><blockquote>
# <p>203</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>14</td>
# <td><blockquote>
# <p>126</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>5</td>
# <td><blockquote>
# <p>115</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>15</td>
# <td><blockquote>
# <p>103</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>16</td>
# <td><blockquote>
# <p>67</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>17</td>
# <td><blockquote>
# <p>58</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>4</td>
# <td><blockquote>
# <p>57</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>18</td>
# <td><blockquote>
# <p>42</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>19</td>
# <td><blockquote>
# <p>32</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>20</td>
# <td><blockquote>
# <p>26</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>3</td>
# <td><blockquote>
# <p>15</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>21</td>
# <td><blockquote>
# <p>14</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>23</td>
# <td><blockquote>
# <p>9</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>22</td>
# <td><blockquote>
# <p>6</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>27</td>
# <td><blockquote>
# <p>2</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>24</td>
# <td><blockquote>
# <p>2</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>1</td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>26</td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>29</td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>2</td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>25</td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > Name: Rings, dtype: int64
# >
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20139in" />
#
# <table>
# <thead>
# <tr class="header">
# <th>[8]: Sex</th>
# <th><blockquote>
# <p>0</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Length</p>
# </blockquote></td>
# <td><blockquote>
# <p>0</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Diameter</p>
# </blockquote></td>
# <td><blockquote>
# <p>0</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>Height</p>
# </blockquote></td>
# <td><blockquote>
# <p>0</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Whole weight</p>
# </blockquote></td>
# <td><blockquote>
# <p>0</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>Shucked weight</p>
# </blockquote></td>
# <td><blockquote>
# <p>0</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Viscera weight</p>
# </blockquote></td>
# <td><blockquote>
# <p>0</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>Shell weight</p>
# </blockquote></td>
# <td><blockquote>
# <p>0</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Rings</p>
# </blockquote></td>
# <td><blockquote>
# <p>0</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# dtype: int64
#
# 5
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image20.png" style="width:6.51389in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image22.png" style="width:1.48056in;height:0.20075in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image23.png" style="width:6.48611in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image24.png" style="width:6.51389in;height:0.33333in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image25.png" style="width:1.48194in;height:0.20026in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" />
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20139in" />
# >
# > \[9\]: False 4177
# >
# > dtype: int64
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>1</strong></th>
# <th><blockquote>
# <p><strong>Data visualization(EDA Analysis)</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20139in" /></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# \[12\]: \<AxesSubplot:xlabel='Length'\>
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image19.png" style="width:4.8875in;height:3.63889in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# \[13\]: \<AxesSubplot:xlabel='Length'\>
#
# 6
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image26.png" style="width:4.8875in;height:3.63889in" />
#
# 7
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image28.png" style="width:6.5in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" />
#
# \[16\]: sns.boxplot(data=d,x="Diameter")
#
# \[16\]: \<AxesSubplot:xlabel='Diameter'\>
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image27.png" style="width:4.8875in;height:3.63889in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# \[18\]: \<AxesSubplot:xlabel='Height'\>
#
# 8
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image30.png" style="width:6.51389in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image31.png" style="width:1.37639in;height:0.2002in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" />
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image29.png" style="width:4.8875in;height:3.63889in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# \[20\]: \<AxesSubplot:xlabel='Length', ylabel='Height'\>
#
# 9
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image32.png" style="width:5.44306in;height:3.63889in" />
#
# \[21\]: sns.scatterplot(data=d,x="Length",y="Height")
#
# \[21\]: \<AxesSubplot:xlabel='Length', ylabel='Height'\>
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image33.png" style="width:5.35972in;height:3.63889in" />
#
# 10
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image34.png" style="width:4.8875in;height:3.63889in" />
#
# \[24\]: sns.boxplot(data=d,x="Shucked weight")
#
# \[24\]: \<AxesSubplot:xlabel='Shucked weight'\>
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image35.png" style="width:4.8875in;height:3.63889in" />
#
# 12
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image38.png" style="width:6.51389in;height:0.30556in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74028in;height:0.20008in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image39.png" style="width:6.51389in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image25.png" style="width:1.48056in;height:0.20008in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image40.png" style="width:6.51389in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# \[25\]: Index(\['Sex', 'Length', 'Diameter', 'Height', 'Whole weight',
# 'Shucked weight',
# 'Viscera weight', 'Shell weight', 'Rings'\],
# dtype='object')
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# \[27\]: \<AxesSubplot:xlabel='Viscera weight'\>
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image36.png" style="width:4.8875in;height:3.63889in" />
#
# |                                                                                                                                                                                                                                                   |
# |---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image37.png" style="width:0.31806in;height:0.2in" /> |
#
# \[28\]: \<AxesSubplot:xlabel='Shell weight'\>
#
# 13
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image41.png" style="width:4.8875in;height:3.63889in" />
#
# \[29\]: sns.boxplot(data=d,x="Rings")
#
# \[29\]: \<AxesSubplot:xlabel='Rings'\>
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image42.png" style="width:4.91528in;height:3.63889in" />
#
# 14
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image46.png" style="width:6.51389in;height:2.15278in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image47.png" style="width:0.52917in;height:0.19969in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10556in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10417in;height:0.20833in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10555in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10417in;height:0.20833in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image48.png" style="width:0.21111in;height:0.20596in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image49.png" style="width:0.63333in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.2125in;height:0.20238in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image49.png" style="width:0.63333in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image49.png" style="width:0.63333in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image49.png" style="width:0.63333in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image25.png" style="width:1.48194in;height:0.20026in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31944in;height:0.20282in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10556in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74028in;height:0.20007in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10417in;height:0.20833in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image3.png" style="width:0.63472in;height:0.19491in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image3.png" style="width:0.63472in;height:0.19491in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52778in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10556in;height:0.21111in" />
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image43.png" style="width:4.8875in;height:4.88889in" />
# >
# > **2** **Removing Outliners**
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20278in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.2in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image44.png" style="width:2.32778in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.2in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10555in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image45.png" style="width:3.93056in;height:0.31944in" />
#
# 16
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image50.png" style="width:6.51389in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image49.png" style="width:0.63333in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image51.png" style="width:6.55556in;height:0.51389in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image25.png" style="width:1.48194in;height:0.20026in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42222in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image52.png" style="width:1.37639in;height:0.1952in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10555in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image53.png" style="width:1.26806in;height:0.19547in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10417in;height:0.20833in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# \[44\]: Sex Length Diameter Height Whole weight Shucked weight Viscera
# weight \\
# 0 M 0.455 0.365 0.095 0.5140 0.2245 0.1010
#
# 1 M 0.350 0.265 0.090 0.2255 0.0995 0.0485
#
# 2 F 0.530 0.420 0.135 0.6770 0.2565 0.1415
#
# 3 M 0.440 0.365 0.125 0.5160 0.2155 0.1140
#
# 4 I 0.330 0.255 0.080 0.2050 0.0895 0.0395
#
# > Shell weight Rings Age
#
# <table>
# <thead>
# <tr class="header">
# <th>0</th>
# <th>0.150</th>
# <th><blockquote>
# <p>15 16.5</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>1</td>
# <td>0.070</td>
# <td><blockquote>
# <p>7 8.5</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>2</td>
# <td>0.210</td>
# <td><blockquote>
# <p>9 10.5</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>3</td>
# <td>0.155</td>
# <td><blockquote>
# <p>10 11.5</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>4</td>
# <td>0.055</td>
# <td><blockquote>
# <p>7 8.5</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20139in" /></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image37.png" style="width:0.31806in;height:0.2in" /></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# \[45\]: \<AxesSubplot:\>
#
# 17
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image55.png" style="width:6.55556in;height:3.13889in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63611in;height:0.20035in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image12.png" style="width:0.95139in;height:0.20029in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63611in;height:0.20035in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image12.png" style="width:0.95139in;height:0.20029in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image49.png" style="width:0.63333in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.2125in;height:0.20238in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63611in;height:0.20035in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image12.png" style="width:0.95139in;height:0.20029in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63611in;height:0.20035in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image12.png" style="width:0.95139in;height:0.20029in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image49.png" style="width:0.63333in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.2125in;height:0.20238in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63611in;height:0.20035in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image56.png" style="width:1.26805in;height:0.20048in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image12.png" style="width:0.95278in;height:0.20059in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63611in;height:0.20035in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image56.png" style="width:1.26805in;height:0.20048in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image12.png" style="width:0.95278in;height:0.20059in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10556in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image49.png" style="width:0.63333in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10417in;height:0.20833in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10556in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10555in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10556in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10417in;height:0.20833in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10555in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10556in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42083in;height:0.2004in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10417in;height:0.20833in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.27083in;height:0.20013in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image15.png" style="width:0.10555in;height:0.21111in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image57.png" style="width:0.1125in;height:0.1125in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52778in;height:0.20106in" />
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image54.png" style="width:5.85in;height:4.0375in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20278in" />
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20278in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.2in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image9.png" style="width:1.05833in;height:0.2in" />
#
# 18
#
# > **3 Split the data into dependent and independent variables.Check
# > for**
# >
# > **Categorical columns and perform encoding**
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image58.png" style="height:0.38889in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.20139in" />
#
# > **4** **Scale the independent**
# >
# > variables
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" />
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image59.png" style="width:5.34722in;height:0.69444in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image21.png" style="width:1.26944in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52778in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image12.png" style="width:0.95139in;height:0.20029in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image16.png" style="width:0.84583in;height:0.2002in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52778in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image52.png" style="width:1.375in;height:0.195in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image3.png" style="width:0.63611in;height:0.19534in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image25.png" style="width:1.48194in;height:0.20026in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image60.png" style="width:1.69167in;height:0.2002in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image60.png" style="width:1.69167in;height:0.2002in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image61.png" style="width:6.55556in;height:0.88889in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image62.png" style="width:0.425in;height:0.195in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74028in;height:0.20008in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" />
#
# \[50\]: array(\[\[ 1.15517188, -0.57962568, -0.43426571, …, -
#
# > 0.61179664, -0.72983642, -0.64298618\],
# >
# > \[ 1.15517188, -1.46650489, -1.4556039 , …, -
# >
# > 1.19199725, -1.21854392, -1.23398399\],
# > \[-0.05270635, 0.05385947, 0.12747029, …, -
# > 0.46326529,
# > -0.35283349, -0.19973781\],
# > …,
# > \[ 1.15517188, 0.64511228, 0.6892063 , …, 0.78532642, 1.00623881,
# > 0.52423451\],
# > \[-0.05270635, 0.856274 , 0.79134012, …, 0.81085524, 0.75955788,
# > 0.43558484\],
# > \[ 1.15517188, 1.57422383, 1.50627685, …, 2.73480045, 1.83471439,
# > 1.90569191\]\])
#
# <table>
# <thead>
# <tr class="header">
# <th><strong>5</strong></th>
# <th><blockquote>
# <p><strong>Model Building</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><strong>6</strong></td>
# <td><blockquote>
# <p><strong>Linear Regression</strong></p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>[51]: <strong>from sklearn.model_selection import</strong> train_test_split</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p><strong>from sklearn import</strong> metrics</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>x_train,x_test,y_train,y_test=train_test_split(x1,y,tes</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>t_size=0.</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>↪2,random_state=42)</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# > x_train.shape,x_test.shape
#
# 19
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image63.png" style="width:2.22083in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image64.png" style="width:0.425in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20278in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20278in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image65.png" style="width:1.90417in;height:0.20278in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image66.png" style="height:0.55556in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20417in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20417in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image65.png" style="width:1.90417in;height:0.20139in" />
#
# > **7** **Lasso**
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20278in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image64.png" style="width:0.425in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20278in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image65.png" style="width:1.90417in;height:0.20139in" />
#
# > **8** **Ridge**
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20417in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image64.png" style="width:0.425in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20278in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image65.png" style="width:1.90417in;height:0.20139in" />
#
# **9** **Prediction**
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20139in" />
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image67.png" style="width:4.625in;height:0.31944in" />\[55\]:
# (array(\[1.15517188, 0.56064759, 0.94454085, 0.28941484,
# 0.66861919,
#
# > 0.59734142, 0.79679274, 0.797571 \]),
# >
# > 15.5)
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" />
#
# \[56\]: (array(\[1.15517188, 0.89850634, 1.09774158, 0.68448704,
# 1.10789396,
# 0.61126624, 1.57872474, 1.57325563\]),
#
# > 10.5)
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20139in" />
#
# \[57\]: array(\[13.06004481\])
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20139in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.20139in" />
#
# > <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image68.png" style="width:4.40278in;height:0.31944in" />
#
# <img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image69.png" style="width:4.48611in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image70.png" style="width:4.29167in;height:0.88889in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image56.png" style="width:1.26806in;height:0.20048in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image60.png" style="width:1.69305in;height:0.20036in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image71.png" style="width:2.11528in;height:0.2005in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image71.png" style="width:2.11528in;height:0.2005in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74028in;height:0.20008in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image13.png" style="width:1.16528in;height:0.20091in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image8.png" style="width:0.52917in;height:0.20159in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image72.png" style="width:2.11667in;height:0.20016in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image72.png" style="width:2.11667in;height:0.20016in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image73.png" style="width:6.55556in;height:0.88889in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74028in;height:0.20008in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image56.png" style="width:1.26806in;height:0.20048in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image47.png" style="width:0.52917in;height:0.19969in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image71.png" style="width:2.11528in;height:0.2005in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image71.png" style="width:2.11528in;height:0.2005in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image74.png" style="width:6.55556in;height:0.88889in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74028in;height:0.20008in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image56.png" style="width:1.26806in;height:0.20048in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image6.png" style="width:0.63472in;height:0.19991in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image47.png" style="width:0.52917in;height:0.19969in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image13.png" style="width:1.16389in;height:0.20067in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10556in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image1.png" style="width:0.42361in;height:0.20172in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10694in;height:0.2037in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74167in;height:0.20045in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74167in;height:0.20045in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image75.png" style="width:6.48611in;height:0.31944in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74167in;height:0.20045in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image11.png" style="width:0.74028in;height:0.20007in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10555in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image2.png" style="width:0.10417in;height:0.19841in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image60.png" style="width:1.69167in;height:0.2002in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31667in;height:0.20106in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image10.png" style="width:0.31806in;height:0.20194in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image60.png" style="width:1.69167in;height:0.2002in" /><img src="attachment:vertopal_4b269cbcf8814626b188b78ff8e6df51/media/image7.png" style="width:0.21111in;height:0.20106in" />
#
# 20
#
# \[58\]: array(\[15.2756354\])
#
# 21
